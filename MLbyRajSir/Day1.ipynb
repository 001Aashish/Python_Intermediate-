# %%
# ENVIRONMENT SETUP WITH MINIFORGE (LOCAL VENV)
# 
# ### Why Miniforge & Local Envs?
# * **Miniforge:** Uses `conda-forge` by default, avoiding Anaconda's commercial licensing restrictions.
# * **Local Prefix (`./.venv`):** Keeps all dependencies inside your project folder instead of a central global directory. This makes the project highly portable and clear.
# 
# > **Note:** Run the following commands in your **Terminal / Command Prompt**, not inside the notebook cells.

# %%
# ### Terminal Commands for Setup
# 
# ```bash
# # 1. Navigate to your project directory
# cd path/to/your/project_folder
# 
# # 2. Create the localized environment inside the project folder
# conda create --prefix ./.venv python=3.11 -y
# 
# # 3. Activate the local environment
# # On macOS / Linux:
# conda activate ./.venv
# # On Windows:
# conda activate .\.venv
# 
# # 4. Install Jupyter Notebook into this specific environment
# conda install jupyter -y
# 
# # 5. Launch the notebook server
# jupyter notebook
# ```

# %%
# %% [markdown]
# ### Verifying Your Notebook Kernel
# Run the cell below inside your Jupyter Notebook to ensure it is using the correct, localized Python interpreter.

# %%
import sys

# This should point to: path/to/your/project_folder/.venv/bin/python
print("Current Python Executable:", sys.executable)
# Out:
# Current Python Executable: /home/aashish/Documents/House/Room0/Python-Inter/venv/bin/python
